# %%
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
score_cols = ["math score", "reading score", "writing score"]

# %%
df["total_score"] = df[score_cols].sum(axis=1)
df["average_score"] = df[score_cols].mean(axis=1)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  average_score
# 0          218      72.666667
# 1          247      82.333333
# 2          278      92.666667
# ...

# %%
def grade_assign(avg):
    if avg >= 75:
        return "A"
    elif avg >= 60:
        return "B"
    elif avg >= 50:
        return "C"
    elif avg >= 40:
        return "D"
    else:
        return "F"

# %%
df["grade"] = df["average_score"].apply(grade_assign)
df[["average_score", "grade"]].head()
# Out:
#    average_score grade
# 0      72.666667     B
# 1      82.333333     A
# 2      92.666667     A
# 3      49.333333     D
# 4      76.333333     A

# %%
df["rank"] = df["average_score"].rank(ascending=False, method="min").astype(int)
df.sort_values("rank").head()
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
# 916    male        group E           bachelor's degree  standard
# 114  female        group E           bachelor's degree  standard
# 179  female        group D            some high school  standard
#
#     test preparation course  math score  reading score  writing score  \
# 458                    none         100            100            100
# 962                    none         100            100            100
# 916               completed         100            100            100
# 114               completed          99            100            100
# 179               completed          97            100            100
#
#      total_score  average_score grade  rank
# 458          300     100.000000     A     1
# 962          300     100.000000     A     1
# ...

# %%
df["grade"].value_counts()
# Out:
# grade
# B    391
# A    324
# C    182
# D     73
# F     30
# Name: count, dtype: int64

# %%
df[score_cols].mean()
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %% [markdown]
# df.sort_values("rank").head(10)

# %% [markdown]
# ## Grade Distribution

# %%
df["grade"].value_counts()
# Out:
# grade
# B    391
# A    324
# C    182
# D     73
# F     30
# Name: count, dtype: int64

# %% [markdown]
# ## Average score by gender

# %%
df.groupby("gender")[["math score", "reading score", "writing score"]].mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %% [markdown]
# ## Average score by test Preparation

# %%
df.groupby("test preparation course")[["math score", "reading score", "writing score"]].mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                 69.695531      73.893855      74.418994
# none                      64.077882      66.534268      64.504673

# %% [markdown]
# ## Average score by test Lunch

# %%
df.groupby("lunch")[["math score", "reading score", "writing score"]].mean()
# Out:
#               math score  reading score  writing score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %% [markdown]
# ## Top 10 Students
#
# Top performing students sorted by specified columns

# %%
df.sort_values('rank').head(10)[["gender", "lunch", "test preparation course", "average_score", "grade"]]
# Out:
#      gender         lunch test preparation course  average_score grade
# 458  female      standard                    none     100.000000     A
# 962  female      standard                    none     100.000000     A
# 916    male      standard               completed     100.000000     A
# 114  female      standard               completed      99.666667     A
# 179  female      standard               completed      99.000000     A
# 712  female      standard                    none      99.000000     A
# 625    male      standard               completed      98.666667     A
# 165  female      standard               completed      98.666667     A
# 149    male  free/reduced               completed      97.666667     A
# 903  female  free/reduced               completed      97.666667     A

# %% [markdown]
# ## Bottom 10 Students
#
# Bottom 10 students sorted by specified columns

# %%
df.sort_values('rank').tail(10)[["gender", "lunch", "test preparation course", "average_score", "grade"]]
# Out:
#      gender         lunch test preparation course  average_score grade
# 211    male  free/reduced                    none      30.000000     F
# 787  female      standard                    none      29.666667     F
# 338  female  free/reduced                    none      29.666667     F
# 601  female      standard                    none      29.333333     F
# 76     male      standard                    none      26.000000     F
# 17   female  free/reduced                    none      26.000000     F
# 327    male  free/reduced                    none      23.333333     F
# 596    male  free/reduced                    none      23.000000     F
# 980  female  free/reduced                    none      18.333333     F
# 59   female  free/reduced                    none       9.000000     F

# %% [markdown]
# ## Overall Summary stats

# %%
df[["math score", "reading score", "writing score"]].describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000
